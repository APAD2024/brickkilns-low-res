# %%
import os
import matplotlib.pyplot as plt
import geopandas as gpd
import shutil
import numpy as np
import pandas as pd
import rasterio
from rasterio.plot import show
import ee
import geemap
from geemap import ml
import requests
import csv
import rasterio
from rasterio.transform import from_origin
from rasterio.enums import Resampling
import matplotlib.pyplot as plt
import cv2
from geopy.distance import geodesic
from joblib import load
from concurrent.futures import ThreadPoolExecutor, as_completed
import boto3
import io
import fiona
import tempfile
import logging
import csv
import threading
#from keys import *

from concurrent.futures import ThreadPoolExecutor
import concurrent.futures

# %%
lock = threading.Lock()  # Create a lock for file access
text_lock = threading.Lock()
output_lock = threading.Lock()
batch_lock = threading.Lock()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
def mask_s2clouds(image):
    qa = image.select('QA60')

    # Bits 10 and 11 are clouds and cirrus, respectively.
    cloud_bit_mask = 1 << 10
    cirrus_bit_mask = 1 << 11

    # Both flags should be set to zero, indicating clear conditions.
    mask = qa.bitwiseAnd(cloud_bit_mask).eq(0) \
        .And(qa.bitwiseAnd(cirrus_bit_mask).eq(0))

    return image.updateMask(mask).divide(10000)

# Define the NDVI calculation function
def add_ndvi(image):
    ndvi = image.normalizedDifference(['B8', 'B4']).rename('NDVI')
    return image.addBands(ndvi)

# Define the clipping function
def clipper(image,ee_geometry):
    return image.clip(ee_geometry)


def display_sentinel2image(Map, ee_geometry, start_date, end_date, bands, ee_classifier):

    roi = ee_geometry
    

    user_image = ee.ImageCollection('COPERNICUS/S2_SR_HARMONIZED') \
        .filterBounds(roi) \
        .filterDate(start_date, end_date) \
        .filter(ee.Filter.lt('CLOUDY_PIXEL_PERCENTAGE', 2)) \
        .map(mask_s2clouds) \
        .map(add_ndvi) \
        .map(lambda img: clipper(img, ee_geometry)) \
        .median().select(bands)

    #Map.add_layer(user_image, {'bands': ['B4', 'B3', 'B2'], 'min': 0, 'max': 0.3}, 'user_image')

    return user_image


def are_close(coord1, coord2, threshold):
    return geodesic(coord1, coord2).meters <= threshold

# Clustering function
def cluster_coordinates(coordinates, threshold):
    clusters = []
    for coord in coordinates:
        found_cluster = False
        for cluster in clusters:
            for c in cluster:
                if are_close(coord, c, threshold):
                    cluster.append(coord)
                    found_cluster = True
                    break
            if found_cluster:
                break
        if not found_cluster:
            clusters.append([coord])
    return clusters

def find_center(coordinates):
    if not coordinates:
        return None  
    x_coords, y_coords = zip(*coordinates)

    center_x = sum(x_coords) / len(x_coords)
    center_y = sum(y_coords) / len(y_coords)

    return (center_x, center_y)

def remove_isolated_pixels(coordinates, threshold_distance):
    if not coordinates:
        return [] 
    
    isolated_pixels = set()

    for i, coord in enumerate(coordinates):

        if coord in isolated_pixels:
            continue

        isolated = True

        for j, other_coord in enumerate(coordinates):
            if i != j: 
                distance = geodesic(coord, other_coord).meters
                if distance <= threshold_distance:
                    isolated = False 
                    break 

        if isolated:
            isolated_pixels.add(coord) 

    filtered_coordinates = [coord for coord in coordinates if coord not in isolated_pixels]

    return filtered_coordinates

def write_centers_to_csv(centers, csv_file):
    with output_lock:
        with open(csv_file, 'a', newline='') as file:
            writer = csv.writer(file)
            for center in centers:
                writer.writerow(center)

def write_to_unused_csv(file_name):
    # Check if the CSV file exists
    with lock:
        # Open the CSV file in append mode
        with open(unused_files_csv, mode='a', newline='') as csvfile:
            writer = csv.writer(csvfile)
            writer.writerow([file_name])

def process_sentinel_and_detect_red_pixels(shapefile, start_date, end_date, feature_names, rf_classifier, i):
    # Convert shapefile to Earth Engine object
    ee_geometry = geemap.shp_to_ee(shapefile)

    # Display Sentinel-2 image
    sentinel_image = display_sentinel2image(Map, ee_geometry, start_date, end_date, feature_names, None)

    # Export the classified image
    url = sentinel_image.getDownloadURL({
        'name': 'sentinel_image',
        'bands': ['B4', 'B3', 'B2'],
        'scale': 10,
        'region': ee_geometry.geometry(),
        'format': 'GEO_TIFF'
    })
    
    response = requests.get(url)
    file_like_object = io.BytesIO(response.content)

    with rasterio.open(file_like_object) as src:
        src = src.read()
        src = src * 2.5
        #print('Original image:')
        #show(src)

    file_like_object.seek(0)

    with rasterio.open(file_like_object) as src:
        width = src.width
        height = src.height
        transforms = src.transform

        pixel_data = []
        for row in range(height):
            for col in range(width):
                b4_value = src.read(1, window=((row, row+1), (col, col+1)))
                b3_value = src.read(2, window=((row, row+1), (col, col+1)))
                b2_value = src.read(3, window=((row, row+1), (col, col+1)))
                lon, lat = src.xy(row, col)
                pixel_data.append([b4_value[0][0], b3_value[0][0], b2_value[0][0], lat, lon])

    df = pd.DataFrame(pixel_data, columns=['B4', 'B3', 'B2', 'Latitude', 'Longitude'])

    X = df[['B4', 'B3', 'B2']]
    y_pred = rf_classifier.predict(X)
    df['landcover'] = y_pred

    output_memfile = io.BytesIO()

    with rasterio.MemoryFile() as memfile:
        with memfile.open(driver='GTiff', width=width, height=height, count=4,
                          dtype=np.uint8, crs='EPSG:4326', transform=transforms) as dst:
            dst.write(df['B4'].values.reshape(height, width), 1)
            dst.write(df['B3'].values.reshape(height, width), 2)
            dst.write(df['B2'].values.reshape(height, width), 3)
            dst.write(df['landcover'].values.reshape(height, width), 4)

        output_memfile = memfile.read()

    with rasterio.MemoryFile(output_memfile) as memfile:
        with memfile.open() as src:
            mask_band = src.read(4)

    new_image = np.zeros((mask_band.shape[0], mask_band.shape[1], 3), dtype=np.uint8)
    for value in [0, 1, 2]:
        if value == 0:
            new_image[mask_band == value] = [255, 0, 0] 
        else:
            new_image[mask_band == value] = [0, 0, 0] 

   # plt.imshow(new_image)
    #plt.axis('off')
    #plt.show()

    kernel_closed = np.ones((3, 3), np.uint8)
    image_closed = cv2.morphologyEx(new_image, cv2.MORPH_CLOSE, kernel_closed)
    
    #print('Closed image:')
    #plt.imshow(image_closed)
    #plt.axis('off')
    #plt.show()

    red_points = np.argwhere((image_closed == [255, 0, 0]).all(axis=2))
    red_coordinates = [transforms * (point[1], point[0]) for point in red_points]

    if len(red_coordinates) > 0:
        red_coordinates = remove_isolated_pixels(red_coordinates, 10)
        clusters = cluster_coordinates(red_coordinates, 25)
        centers = [find_center(cluster) for cluster in clusters]
        centers = [(center[1], center[0]) for center in centers]
    
        if len(centers) > 7:
            centers = [centers[0]]
       
        print('Red pixel clusters:')
        print(centers)
        write_centers_to_csv(centers, csv_file)

    else:
        print('No red points found')

def process_shapefile(shapefile_path, start_date, end_date, feature_names, rf_classifier, index):
    try:
        process_sentinel_and_detect_red_pixels(shapefile_path, start_date, end_date, feature_names, rf_classifier, index)
    except Exception as e:
        print(f"Error processing file {shapefile_path}: {e}")
        write_to_unused_csv(shapefile_path)

def process_batch(batch, batch_number, text_file, batch_lock):
    with batch_lock:
        print(f'Processing batch number: {batch_number}')
        with open(text_file, 'w') as f:
            f.write(f'{batch_number}')
    with ThreadPoolExecutor(max_workers=os.cpu_count()) as executor:
        futures = [
            executor.submit(process_shapefile, file, start_date, end_date, feature_names, rf_classifier, 0)
            for file in batch if file.endswith('.shp')
        ]
        for future in concurrent.futures.as_completed(futures):
            try:
                future.result()
            except Exception as e:
                print(f'Error processing file: {e}')
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
rf_classifier = load('../../models/RF_model_v3.pkl')
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
feature_names = ['B4', 'B3', 'B2']
#start date should be 1st june 2023
start_date = '2023-06-01'
end_date = '2023-06-15'
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
csv_file = '../Data/coordinate_csvs_2/centers_0_1000.csv'
unused_files_csv = '../Data/error_csvs_2/not_processed_0_1000_2.csv'
text_file = '../Data/latest_processed/latest_processed_0_1000.txt'
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
ee.Initialize()
Map = geemap.Map()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
import os

# Define the directory containing the shapefiles
shapefile_directory = '../../grids_final_pak_final_version'

# Get a list of files in the directory
files = os.listdir(shapefile_directory)
# Check if there are any files in the directory
if files:
    first_file = files[0]
    print(f"The first file in the directory is: {first_file}")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# The first file in the directory is: grid_0.shp

# %%
folder_path = '../../grids_final_pak_final_version'
shapefiles = []

# Walk through the directory and get file paths
for root, dirs, files in os.walk(folder_path):
    for file in files:
        shapefiles.append(os.path.join(root, file))

print(f"Total files found: {len(shapefiles)}")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Total files found: 1074872

# %%
shapefiles = shapefiles[:1074800]
batch_size = 200
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
shapefile_batches = [shapefiles[i:i + batch_size] for i in range(0, len(shapefiles), batch_size)]
len(shapefile_batches)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# 5374

# %%
shapefile_batches = shapefile_batches[748:1000]
len(shapefile_batches)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# 252

# %%
#shapefile_batches[-1] = shapefile_batches[-1][1:]
shapefile_batches[100]
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# ['../../grids_final_pak_final_version/grid_84791.dbf',
#  '../../grids_final_pak_final_version/grid_84792.shp',
#  '../../grids_final_pak_final_version/grid_84792.dbf',
#  '../../grids_final_pak_final_version/grid_84793.shp',
#  '../../grids_final_pak_final_version/grid_84793.dbf',
#  '../../grids_final_pak_final_version/grid_84794.shp',
#  '../../grids_final_pak_final_version/grid_84794.dbf',
#  '../../grids_final_pak_final_version/grid_84795.shp',
#  '../../grids_final_pak_final_version/grid_84795.dbf',
#  '../../grids_final_pak_final_version/grid_84796.shp',
#  '../../grids_final_pak_final_version/grid_84796.dbf',
#  '../../grids_final_pak_final_version/grid_84797.shp',
#  '../../grids_final_pak_final_version/grid_84797.dbf',
#  '../../grids_final_pak_final_version/grid_84798.shp',
#  '../../grids_final_pak_final_version/grid_84798.dbf',
#  '../../grids_final_pak_final_version/grid_84799.shp',
#  '../../grids_final_pak_final_version/grid_84799.dbf',
#  '../../grids_final_pak_final_version/grid_84800.shp',
#  '../../grids_final_pak_final_version/grid_84800.dbf',
#  '../../grids_final_pak_final_version/grid_84801.shp',
#  '../../grids_final_pak_final_version/grid_84801.dbf',
#  '../../grids_final_pak_final_version/grid_84802.shp',
#  '../../grids_final_pak_final_version/grid_84802.dbf',
#  '../../grids_final_pak_final_version/grid_84803.shp',
#  '../../grids_final_pak_final_version/grid_84803.dbf',
#  '../../grids_final_pak_final_version/grid_84804.shp',
#  '../../grids_final_pak_final_version/grid_84804.dbf',
#  '../../grids_final_pak_final_version/grid_84805.shp',
#  '../../grids_final_pak_final_version/grid_84805.dbf',
#  '../../grids_final_pak_final_version/grid_84806.shp',
#  '../../grids_final_pak_final_version/grid_84806.dbf',
#  '../../grids_final_pak_final_version/grid_84807.shp',
#  '../../grids_final_pak_final_version/grid_84807.dbf',
#  '../../grids_final_pak_final_version/grid_84808.shp',
#  '../../grids_final_pak_final_version/grid_84808.dbf',
#  '../../grids_final_pak_final_version/grid_84809.shp',
#  '../../grids_final_pak_final_version/grid_84809.dbf',
#  '../../grids_final_pak_final_version/grid_84810.shp',
#  '../../grids_final_pak_final_version/grid_84810.dbf',
#  '../../grids_final_pak_final_version/grid_84811.shp',
#  '../../grids_final_pak_final_version/grid_84811.dbf',
#  '../../grids_final_pak_final_version/grid_84812.shp',
#  '../../grids_final_pak_final_version/grid_84812.dbf',
#  '../../grids_final_pak_final_version/grid_84813.shp',
#  '../../grids_final_pak_final_version/grid_84813.dbf',
#  '../../grids_final_pak_final_version/grid_84814.shp',
#  '../../grids_final_pak_final_version/grid_84814.dbf',
#  '../../grids_final_pak_final_version/grid_84815.shp',
#  '../../grids_final_pak_final_version/grid_84815.dbf',
#  '../../grids_final_pak_final_version/grid_84816.shp',
#  '../../grids_final_pak_final_version/grid_84816.dbf',
#  '../../grids_final_pak_final_version/grid_84817.shp',
#  '../../grids_final_pak_final_version/grid_84817.dbf',
#  '../../grids_final_pak_final_version/grid_84818.shp',
#  '../../grids_final_pak_final_version/grid_84818.dbf',
#  '../../grids_final_pak_final_version/grid_84819.shp',
#  '../../grids_final_pak_final_version/grid_84819.dbf',
#  '../../grids_final_pak_final_version/grid_84820.shp',
#  '../../grids_final_pak_final_version/grid_84820.dbf',
#  '../../grids_final_pak_final_version/grid_84821.shp',
#  '../../grids_final_pak_final_version/grid_84821.dbf',
#  '../../grids_final_pak_final_version/grid_84822.shp',
#  '../../grids_final_pak_final_version/grid_84822.dbf',
#  '../../grids_final_pak_final_version/grid_84823.shp',
#  '../../grids_final_pak_final_version/grid_84823.dbf',
#  '../../grids_final_pak_final_version/grid_84824.shp',
#  '../../grids_final_pak_final_version/grid_84824.dbf',
#  '../../grids_final_pak_final_version/grid_84825.shp',
#  '../../grids_final_pak_final_version/grid_84825.dbf',
#  '../../grids_final_pak_final_version/grid_84826.shp',
#  '../../grids_final_pak_final_version/grid_84826.dbf',
#  '../../grids_final_pak_final_version/grid_84827.shp',
#  '../../grids_final_pak_final_version/grid_84827.dbf',
#  '../../grids_final_pak_final_version/grid_84828.shp',
#  '../../grids_final_pak_final_version/grid_84828.dbf',
#  '../../grids_final_pak_final_version/grid_84829.shp',
#  '../../grids_final_pak_final_version/grid_84829.dbf',
#  '../../grids_final_pak_final_version/grid_84830.shp',
#  '../../grids_final_pak_final_version/grid_84830.dbf',
#  '../../grids_final_pak_final_version/grid_84831.shp',
#  '../../grids_final_pak_final_version/grid_84831.dbf',
#  '../../grids_final_pak_final_version/grid_84832.shp',
#  '../../grids_final_pak_final_version/grid_84832.dbf',
#  '../../grids_final_pak_final_version/grid_84833.shp',
#  '../../grids_final_pak_final_version/grid_84833.dbf',
#  '../../grids_final_pak_final_version/grid_84834.shp',
#  '../../grids_final_pak_final_version/grid_84834.dbf',
#  '../../grids_final_pak_final_version/grid_84835.shp',
#  '../../grids_final_pak_final_version/grid_84835.dbf',
#  '../../grids_final_pak_final_version/grid_84836.shp',
#  '../../grids_final_pak_final_version/grid_84836.dbf',
#  '../../grids_final_pak_final_version/grid_84837.shp',
#  '../../grids_final_pak_final_version/grid_84837.dbf',
#  '../../grids_final_pak_final_version/grid_84838.shp',
#  '../../grids_final_pak_final_version/grid_84838.dbf',
#  '../../grids_final_pak_final_version/grid_84839.shp',
#  '../../grids_final_pak_final_version/grid_84839.dbf',
#  '../../grids_final_pak_final_version/grid_84840.shp',
#  '../../grids_final_pak_final_version/grid_84840.dbf',
#  '../../grids_final_pak_final_version/grid_84841.shp',
#  '../../grids_final_pak_final_version/grid_84841.dbf',
#  '../../grids_final_pak_final_version/grid_84842.shp',
#  '../../grids_final_pak_final_version/grid_84842.dbf',
#  '../../grids_final_pak_final_version/grid_84843.shp',
#  '../../grids_final_pak_final_version/grid_84843.dbf',
#  '../../grids_final_pak_final_version/grid_84844.shp',
#  '../../grids_final_pak_final_version/grid_84844.dbf',
#  '../../grids_final_pak_final_version/grid_84845.shp',
#  '../../grids_final_pak_final_version/grid_84845.dbf',
#  '../../grids_final_pak_final_version/grid_84846.shp',
#  '../../grids_final_pak_final_version/grid_84846.dbf',
#  '../../grids_final_pak_final_version/grid_84847.shp',
#  '../../grids_final_pak_final_version/grid_84847.dbf',
#  '../../grids_final_pak_final_version/grid_84848.shp',
#  '../../grids_final_pak_final_version/grid_84848.dbf',
#  '../../grids_final_pak_final_version/grid_84849.shp',
#  '../../grids_final_pak_final_version/grid_84849.dbf',
#  '../../grids_final_pak_final_version/grid_84850.shp',
#  '../../grids_final_pak_final_version/grid_84850.dbf',
#  '../../grids_final_pak_final_version/grid_84851.shp',
#  '../../grids_final_pak_final_version/grid_84851.dbf',
#  '../../grids_final_pak_final_version/grid_84852.shp',
#  '../../grids_final_pak_final_version/grid_84852.dbf',
#  '../../grids_final_pak_final_version/grid_84853.shp',
#  '../../grids_final_pak_final_version/grid_84853.dbf',
#  '../../grids_final_pak_final_version/grid_84854.shp',
#  '../../grids_final_pak_final_version/grid_84854.dbf',
#  '../../grids_final_pak_final_version/grid_84855.shp',
#  '../../grids_final_pak_final_version/grid_84855.dbf',
#  '../../grids_final_pak_final_version/grid_84856.shp',
#  '../../grids_final_pak_final_version/grid_84856.dbf',
#  '../../grids_final_pak_final_version/grid_84857.shp',
#  '../../grids_final_pak_final_version/grid_84857.dbf',
#  '../../grids_final_pak_final_version/grid_84858.shp',
#  '../../grids_final_pak_final_version/grid_84858.dbf',
#  '../../grids_final_pak_final_version/grid_84859.shp',
#  '../../grids_final_pak_final_version/grid_84859.dbf',
#  '../../grids_final_pak_final_version/grid_84860.shp',
#  '../../grids_final_pak_final_version/grid_84860.dbf',
#  '../../grids_final_pak_final_version/grid_84861.shp',
#  '../../grids_final_pak_final_version/grid_84861.dbf',
#  '../../grids_final_pak_final_version/grid_84862.shp',
#  '../../grids_final_pak_final_version/grid_84862.dbf',
#  '../../grids_final_pak_final_version/grid_84863.shp',
#  '../../grids_final_pak_final_version/grid_84863.dbf',
#  '../../grids_final_pak_final_version/grid_84864.shp',
#  '../../grids_final_pak_final_version/grid_84864.dbf',
#  '../../grids_final_pak_final_version/grid_84865.shp',
#  '../../grids_final_pak_final_version/grid_84865.dbf',
#  '../../grids_final_pak_final_version/grid_84866.shp',
#  '../../grids_final_pak_final_version/grid_84866.dbf',
#  '../../grids_final_pak_final_version/grid_84867.shp',
#  '../../grids_final_pak_final_version/grid_84867.dbf',
#  '../../grids_final_pak_final_version/grid_84868.shp',
#  '../../grids_final_pak_final_version/grid_84868.dbf',
#  '../../grids_final_pak_final_version/grid_84869.shp',
#  '../../grids_final_pak_final_version/grid_84869.dbf',
#  '../../grids_final_pak_final_version/grid_84870.shp',
#  '../../grids_final_pak_final_version/grid_84870.dbf',
#  '../../grids_final_pak_final_version/grid_84871.shp',
#  '../../grids_final_pak_final_version/grid_84871.dbf',
#  '../../grids_final_pak_final_version/grid_84872.shp',
#  '../../grids_final_pak_final_version/grid_84872.dbf',
#  '../../grids_final_pak_final_version/grid_84873.shp',
#  '../../grids_final_pak_final_version/grid_84873.dbf',
#  '../../grids_final_pak_final_version/grid_84874.shp',
#  '../../grids_final_pak_final_version/grid_84874.dbf',
#  '../../grids_final_pak_final_version/grid_84875.shp',
#  '../../grids_final_pak_final_version/grid_84875.dbf',
#  '../../grids_final_pak_final_version/grid_84876.shp',
#  '../../grids_final_pak_final_version/grid_84876.dbf',
#  '../../grids_final_pak_final_version/grid_84877.shp',
#  '../../grids_final_pak_final_version/grid_84877.dbf',
#  '../../grids_final_pak_final_version/grid_84878.shp',
#  '../../grids_final_pak_final_version/grid_84878.dbf',
#  '../../grids_final_pak_final_version/grid_84879.shp',
#  '../../grids_final_pak_final_version/grid_84879.dbf',
#  '../../grids_final_pak_final_version/grid_84880.shp',
#  '../../grids_final_pak_final_version/grid_84880.dbf',
#  '../../grids_final_pak_final_version/grid_84881.shp',
#  '../../grids_final_pak_final_version/grid_84881.dbf',
#  '../../grids_final_pak_final_version/grid_84882.shp',
#  '../../grids_final_pak_final_version/grid_84882.dbf',
#  '../../grids_final_pak_final_version/grid_84883.shp',
#  '../../grids_final_pak_final_version/grid_84883.dbf',
#  '../../grids_final_pak_final_version/grid_84884.shp',
#  '../../grids_final_pak_final_version/grid_84890.shp',
#  '../../grids_final_pak_final_version/grid_84890.dbf',
#  '../../grids_final_pak_final_version/grid_84891.shp',
#  '../../grids_final_pak_final_version/grid_84891.dbf',
#  '../../grids_final_pak_final_version/grid_84892.shp',
#  '../../grids_final_pak_final_version/grid_84892.dbf',
#  '../../grids_final_pak_final_version/grid_84893.shp',
#  '../../grids_final_pak_final_version/grid_84893.dbf',
#  '../../grids_final_pak_final_version/grid_85024.dbf',
#  '../../grids_final_pak_final_version/grid_85025.shp',
#  '../../grids_final_pak_final_version/grid_85025.dbf',
#  '../../grids_final_pak_final_version/grid_85026.shp',
#  '../../grids_final_pak_final_version/grid_85026.dbf',
#  '../../grids_final_pak_final_version/grid_85027.shp']

# %%
for batch_number, batch in enumerate(shapefile_batches):
    process_batch(batch, batch_number + 748, text_file, batch_lock)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Processing batch number: 748
# Error processing file ../../grids_final_pak_final_version/grid_74857.shp: '/vsipythonfilelike/d7009b58-3568-4d90-9377-f80fbf5141b7/d7009b58-3568-4d90-9377-f80fbf5141b7' not recognized as a supported file format.
# Error processing file ../../grids_final_pak_final_version/grid_74797.shp: '/vsipythonfilelike/138c4239-0161-409f-9b91-67ef37c10188/138c4239-0161-409f-9b91-67ef37c10188' not recognized as a supported file format.
# Error processing file ../../grids_final_pak_final_version/grid_74853.shp: '/vsipythonfilelike/093692ef-c486-4c78-8211-3c32a5d6db1a/093692ef-c486-4c78-8211-3c32a5d6db1a' not recognized as a supported file format.
# Error processing file ../../grids_final_pak_final_version/grid_74792.shp: '/vsipythonfilelike/1d046ad8-b534-426d-b0f0-576cdac3da80/1d046ad8-b534-426d-b0f0-576cdac3da80' not recognized as a supported file format.
# Error processing file ../../grids_final_pak_final_version/grid_74820.shp: '/vsipythonfilelike/9c8827e1-5aab-4256-ae67-c15e4c607647/9c8827e1-5aab-4256-ae67-c15e4c607647' not recognized as a supported file format.
# Error processing file ../../grids_final_pak_final_version/grid_74862.shp: '/vsipythonfilelike/68d292b6-c933-4dcb-9d4c-a639b032eb98/68d292b6-c933-4dcb-9d4c-a639b032eb98' not recognized as a supported file format.
# Error processing file ../../grids_final_pak_final_version/grid_74957.shp: '/vsipythonfilelike/59f66bde-06d7-42cd-9564-9217dbd79dee/59f66bde-06d7-42cd-9564-9217dbd79dee' not recognized as a supported file format.
# Error processing file ../../grids_final_pak_final_version/grid_74821.shp: '/vsipythonfilelike/4322dbca-f7da-4718-b58d-f12696f4b66f/4322dbca-f7da-4718-b58d-f12696f4b66f' not recognized as a supported file format.
# Error processing file ../../grids_final_pak_final_version/grid_74851.shp: '/vsipythonfilelike/a404916e-9489-48e7-b0d2-3684fdfd5e2f/a404916e-9489-48e7-b0d2-3684fdfd5e2f' not recognized as a supported file format.
# Red pixel clusters:
# []
# No red points found
# No red points found
# No red points found
# No red points found
# No red points found
# No red points found
# No red points found
# No red points found
# No red points found
# Red pixel clusters:
# []
# No red points found
# No red points found
# Red pixel clusters:
# [(27.735798807539666, 67.91119817498124), (27.72708514928371, 67.90805407148682)]
# Red pixel clusters:
# []
# Red pixel clusters:
# [(27.92282804969335, 67.90329300048099), (27.91927970432108, 67.91308463707789)]
# Red pixel clusters:
# []
# No red points found
# Red pixel clusters:
# []
# Red pixel clusters:
# [(27.68809826595292, 67.90670659856063)]
# Red pixel clusters:
# []
# No red points found
# Red pixel clusters:
# []
# Red pixel clusters:
# [(27.702459490560887, 67.90475867278664), (27.702111984385184, 67.90522437834184)]
# Red pixel clusters:
# [(27.983284668314596, 67.90455064187876), (27.980410059405415, 67.90958120746981)]
# Red pixel clusters:
# []
# No red points found
# Red pixel clusters:
# [(27.863988398583523, 67.90652693550382), (27.863584156705667, 67.91182699568012)]
# No red points found
# No red points found
# Red pixel clusters:
# [(27.92633147930142, 67.90459555764295)]
# Red pixel clusters:
# []
# No red points found
# No red points found
# Red pixel clusters:
# []
# No red points found
# No red points found
# Red pixel clusters:
# []
# No red points found
# No red points found
# Red pixel clusters:
# [(28.203821070565937, 67.90751508231635)]
# No red points found
# Red pixel clusters:
# []
# Red pixel clusters:
# [(27.714014661899768, 67.9071557562027)]
# No red points found
# No red points found
# Red pixel clusters:
# [(27.100061080968285, 67.90881763947831), (27.098803439570517, 67.90832356607206), (27.09862377651369, 67.90805407148682), (27.097815292757982, 67.90816636089734), (27.097860208522185, 67.90787440842999)]
# Red pixel clusters:
# [(27.655489421139382, 67.90410148423669)]
# Red pixel clusters:
# [(27.69748566067197, 67.91083884886758), (27.697153975028606, 67.91182008556255), (27.69582377739635, 67.90549387292708), (27.695464451282703, 67.90697609314587)]
# Red pixel clusters:
# [(27.978793091893998, 67.91056935428234)]
# Red pixel clusters:
# []
# Red pixel clusters:
# [(27.636804463229694, 67.91110834345282), (27.63029167741983, 67.90652693550382), (27.62894420449365, 67.90733541925952), (27.628899288729443, 67.91142275380227)]
# Red pixel clusters:
# []
# No red points found
# Red pixel clusters:
# [(27.671209938611476, 67.90895238677093), (27.670670949441003, 67.90967103899823), (27.66478698433002, 67.90931171288459)]
# Red pixel clusters:
# []
# No red points found
# Red pixel clusters:
# []
# Red pixel clusters:
# []
# Red pixel clusters:
# []
# Red pixel clusters:
# []
# Red pixel clusters:
# [(27.90342443955637, 67.91286005825685), (27.902256629687017, 67.91137783803806), (27.90207696663019, 67.91290497402106), (27.89811381096497, 67.90594567267291), (27.89816929514427, 67.90549387292708)]
# Red pixel clusters:
# []
# Red pixel clusters:
# [(27.6518512442387, 67.91182699568012), (27.64839273039484, 67.90401165270828), (27.647921114870673, 67.90359992486974), (27.646730847119215, 67.91029985969712)]
# Red pixel clusters:
# [(27.85240013141838, 67.90598794633334), (27.85163656342688, 67.90948139466047), (27.847324650063104, 67.91272531096423), (27.847073121783552, 67.91231208593355), (27.844280359378033, 67.91232605972687)]
# Red pixel clusters:
# [(27.05456141182763, 67.909401544413), (27.05404038896284, 67.91024596078007)]
# Red pixel clusters:
# [(27.191509576891647, 67.91290497402106)]
# Red pixel clusters:
# [(27.861473115787987, 67.91308463707789), (27.860395137447046, 67.90446081035034), (27.858808113778437, 67.91206654642254), (27.857161202424216, 67.90535912563446), (27.853235564632616, 67.91132393912102), (27.85300200265874, 67.90482013646398)]
# Red pixel clusters:
# [(27.726546160113237, 67.90859306065728), (27.72295958855866, 67.90727425736786), (27.72305021646588, 67.90786692246928), (27.72084185805908, 67.90877272371411)]
# Red pixel clusters:
# [(27.184996791081783, 67.9102100281687)]
# Red pixel clusters:
# [(27.67767921227478, 67.91246423808478), (27.677902387478163, 67.91227615332218), (27.677453229836104, 67.91182699568012), (27.67471336821954, 67.90805407148682), (27.67435404210589, 67.90742525078794)]
# Red pixel clusters:
# [(27.89776505326642, 67.90526929410605)]
# Red pixel clusters:
# [(27.334193139538897, 67.90325844989313), (27.334072212481416, 67.90464047340716)]
# Red pixel clusters:
# []
# Red pixel clusters:
# [(27.25747800143474, 67.91300122208722)]
# Red pixel clusters:
# []
# Red pixel clusters:
# [(27.205478379559707, 67.9117371641517)]
# Red pixel clusters:
# [(27.154633734478544, 67.90697609314587)]
# Red pixel clusters:
# []
# Red pixel clusters:
# [(27.319492555420158, 67.9038858885685)]
# Red pixel clusters:
# [(27.13715251904959, 67.90951447547734), (27.13711658643821, 67.90917696559197)]
# Red pixel clusters:
# [(27.248687344725855, 67.91101851192442), (27.242893211143286, 67.91290497402106), (27.24199489585917, 67.91209649026536), (27.241654819358754, 67.91298197247399)]
# Red pixel clusters:
# [(27.215314931920815, 67.90329300048099), (27.21495560580717, 67.90356249506623)]
# Red pixel clusters:
# []
# Red pixel clusters:
# [(27.238760960836338, 67.910928680396), (27.231933764677027, 67.90383198965145)]
# Red pixel clusters:
# [(27.175699227891148, 67.91155750109488)]
# Red pixel clusters:
# [(27.203816496284087, 67.91205157450115), (27.203726664755678, 67.9072006719669), (27.203636833227264, 67.91070410157496), (27.202156189000192, 67.90685946975807)]
# Red pixel clusters:
# [(27.267776544513396, 67.90405656847248)]
# Red pixel clusters:
# [(27.230316797165614, 67.90437097882193)]
# Red pixel clusters:
# [(27.31140098049845, 67.90352207087845)]
# Red pixel clusters:
# [(27.29208720188988, 67.904168857883), (27.288467164047816, 67.90802470348709), (27.288797122161796, 67.90383198965145), (27.28795495158293, 67.91286005825684), (27.287269986178792, 67.91308463707789), (27.286134701518, 67.91295143860474)]
# Processing batch number: 749
# No red points found
# Red pixel clusters:
# []
# Red pixel clusters:
# []
# Red pixel clusters:
# []
# Red pixel clusters:
# [(27.480048446150843, 67.91006030895468), (27.480228109207665, 67.91119817498124), (27.47917508406906, 67.90655687934662), (27.47892555204569, 67.9064371039754)]
# No red points found
# Red pixel clusters:
# []
# Red pixel clusters:
# []
# No red points found
# Red pixel clusters:
# []
# Red pixel clusters:
# []
# No red points found
# No red points found
# Red pixel clusters:
# []
# Red pixel clusters:
# []
# Red pixel clusters:
# []
# Red pixel clusters:
# []
# Red pixel clusters:
# []
# No red points found
# Red pixel clusters:
# []
# Red pixel clusters:
# []
# Red pixel clusters:
# [(27.346648626459093, 67.91137783803806), (27.34494182741927, 67.91110834345282)]
# No red points found
# Red pixel clusters:
# []
# Red pixel clusters:
# [(27.372901890637483, 67.90402849611986), (27.372924348519586, 67.90383198965145), (27.37243027511332, 67.90315825318837)]
# No red points found
# No red points found
# No red points found
# No red points found
# No red points found
# Red pixel clusters:
# []
# Red pixel clusters:
# [(27.492227528368232, 67.90726631808384), (27.491501966023364, 67.90652693550382), (27.490828229560275, 67.906347272447)]
# Red pixel clusters:
# [(27.392013548307126, 67.90607777786175)]
# No red points found
# No red points found
# Red pixel clusters:
# []
# No red points found
# Red pixel clusters:
# []
# Red pixel clusters:
# [(27.454760870902874, 67.91200665873694), (27.447978590507773, 67.90553878869129)]
# Red pixel clusters:
# [(27.364480184848862, 67.91303972131368), (27.363961158240258, 67.91213641538909), (27.363087796158478, 67.91308463707789)]
# No red points found
# No red points found
# Red pixel clusters:
# []
# Red pixel clusters:
# []
# No red points found
# Red pixel clusters:
# []
# Red pixel clusters:
# [(27.568116282221634, 67.90717971127694)]
# Red pixel clusters:
# [(27.618074589555803, 67.909401544413), (27.611741466802762, 67.91308463707789), (27.61039399387658, 67.91182699568012)]
# Red pixel clusters:
# [(27.447798927450947, 67.90589811480493)]
# Red pixel clusters:
# [(27.38125301451092, 67.90619969207887), (27.38136851219031, 67.90598794633334), (27.379526965857863, 67.91209649026536), (27.37889814515898, 67.91083884886758), (27.37880831363057, 67.90859306065728)]
# Red pixel clusters:
# [(27.270777734212615, 67.90811123700489), (27.270323132235514, 67.90883533356724)]
# Red pixel clusters:
# []
# Red pixel clusters:
# [(27.541942369226675, 67.90733541925952), (27.537899950448136, 67.91110834345282)]
# No red points found
# Red pixel clusters:
# [(27.562693452289835, 67.90733541925952), (27.558920528096532, 67.9064371039754), (27.55748322364194, 67.91200665873694)]
# Red pixel clusters:
# [(27.502865654367476, 67.90998544934767), (27.502685991310653, 67.9072006719669), (27.501922423319154, 67.90697609314587), (27.501877507554944, 67.91128800650965)]
# Red pixel clusters:
# [(27.42084946892736, 67.90693117738167), (27.420599223955357, 67.90863583757557), (27.419951153643243, 67.90751508231635)]
# Red pixel clusters:
# []
# Red pixel clusters:
# [(27.402883163244972, 67.91191682720853)]
# Red pixel clusters:
# [(27.50178767602653, 67.90751508231635)]
# Red pixel clusters:
# [(27.55342855510953, 67.90839706459529), (27.55335097333499, 67.90769474537318), (27.552722152636107, 67.90904221829935)]
# No red points found
# Red pixel clusters:
# []
# Red pixel clusters:
# [(27.458619135048167, 67.90806754621606), (27.45893803697403, 67.90917696559197), (27.458713458153, 67.90787440842999), (27.45824433794907, 67.90711583107895), (27.457276153698405, 67.90832356607206)]
# Red pixel clusters:
# [(27.591259878324834, 67.9095362917056)]
# Red pixel clusters:
# [(27.52792865079441, 67.91137783803806), (27.526805756689264, 67.9057184517481), (27.523616737430636, 67.90688626161746)]
# Red pixel clusters:
# [(27.426868181330963, 67.90482013646398)]
# Red pixel clusters:
# [(27.60540834404972, 67.91164733262329)]
# Red pixel clusters:
# [(27.5172836146776, 67.91281514249265)]
# Red pixel clusters:
# []
# No red points found
# No red points found
# Red pixel clusters:
# []
# No red points found
# Red pixel clusters:
# []
# Red pixel clusters:
# []
# Red pixel clusters:
# [(28.27424898884091, 67.90455064187876), (28.27424898884091, 67.90675151432484)]
# Red pixel clusters:
# []
# Red pixel clusters:
# []
# No red points found
# No red points found
# Red pixel clusters:
# []
# Red pixel clusters:
# []
# Red pixel clusters:
# []
# Red pixel clusters:
# [(29.30192167387364, 67.91047952275395)]
# No red points found
# Red pixel clusters:
# []
# Red pixel clusters:
# []
# No red points found
# No red points found
# Red pixel clusters:
# []
# No red points found
# Red pixel clusters:
# []
# Red pixel clusters:
# []
# Red pixel clusters:
# []
# Red pixel clusters:
# [(29.148938580988087, 67.90751508231635)]
# Red pixel clusters:
# []
# Red pixel clusters:
# [(27.58030582175028, 67.90613886330108)]
# Red pixel clusters:
# [(27.62671525969493, 67.90930609841405)]
# Red pixel clusters:
# [(27.600782020336503, 67.906347272447)]
# Processing batch number: 750
# Red pixel clusters:
# []
# Red pixel clusters:
# [(28.501721668393202, 67.91267397866228)]
# No red points found
# No red points found
# Red pixel clusters:
# []
# No red points found
# No red points found
# Red pixel clusters:
# [(28.39426391079928, 67.9033828320094)]
# Red pixel clusters:
# []
# No red points found
# Red pixel clusters:
# []
# No red points found
# No red points found
# No red points found
# Red pixel clusters:
# []
# No red points found
# Red pixel clusters:
# []
# Red pixel clusters:
# []
# Red pixel clusters:
# []
# Red pixel clusters:
# []
# Red pixel clusters:
# []
# No red points found
# Red pixel clusters:
# []
# No red points found
# Red pixel clusters:
# [(28.475202117898444, 67.906347272447), (28.474887707549, 67.91290497402106)]
# Red pixel clusters:
# [(28.617944416545036, 67.90473030493557)]
# No red points found
# No red points found
# Red pixel clusters:
# [(28.235890926209006, 67.90814390301523)]
# Red pixel clusters:
# [(28.2403825026296, 67.90679643008905)]
# Red pixel clusters:
# []
# No red points found
# Error processing file ../../grids_final_pak_final_version/grid_75225.shp: Image.select: Band pattern 'B4' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# Red pixel clusters:
# [(28.30281541487591, 67.90976087052664)]
# Error processing file ../../grids_final_pak_final_version/grid_75227.shp: Image.select: Band pattern 'B4' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# Error processing file ../../grids_final_pak_final_version/grid_75226.shp: Image.select: Band pattern 'B4' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# Red pixel clusters:
# []
# Red pixel clusters:
# [(28.254081810712425, 67.91101851192441), (28.253587737306162, 67.90729050349532)]
# Red pixel clusters:
# []
# Red pixel clusters:
# []
# Red pixel clusters:
# [(28.5176924308373, 67.90805407148682), (28.51670428402477, 67.90976087052664), (28.51122456079164, 67.90374215812304)]
# Red pixel clusters:
# [(28.464781660602657, 67.90522437834184), (28.463164693091244, 67.90778457690158)]
# Red pixel clusters:
# [(28.45283406732387, 67.9079642399584), (28.45189083627555, 67.90374215812304), (28.450318784528335, 67.9041464000009), (28.44906114313057, 67.90360741083043), (28.447358427342035, 67.90350532954814), (28.447309428326534, 67.9033828320094)]
# No red points found
# Red pixel clusters:
# []
# No red points found
# No red points found
# Red pixel clusters:
# []
# Red pixel clusters:
# [(28.41339802635102, 67.91164733262329)]
# Red pixel clusters:
# [(28.303444235574794, 67.90967103899823)]
# Red pixel clusters:
# []
# Red pixel clusters:
# []
# Red pixel clusters:
# [(28.52694507826373, 67.90607777786175), (28.5260018472154, 67.90733541925952), (28.5237111432409, 67.91281514249265), (28.52231875455051, 67.90455064187876), (28.521195860445363, 67.90778457690158)]
# Red pixel clusters:
# []
# Red pixel clusters:
# [(28.53341294830939, 67.90805407148682), (28.53153397217344, 67.91059181216444), (28.531571401976944, 67.91047952275395), (28.53004426599394, 67.91245581637901), (28.52793322507626, 67.91209649026536)]
# Red pixel clusters:
# [(28.446186534221386, 67.90482013646398), (28.442054283914437, 67.90504471528502), (28.440796642516666, 67.90526929410605)]
# No red points found
# Red pixel clusters:
# [(28.28484910919352, 67.90360741083043), (28.279189722903567, 67.91303972131368)]
# Red pixel clusters:
# [(28.500669356203236, 67.91227615332218), (28.49981595668332, 67.91047952275395), (28.499366799041262, 67.91128800650965), (28.497803730446893, 67.90330198363382), (28.498019326115084, 67.91012019664029), (28.497974410350878, 67.90365232659462), (28.495683706376372, 67.90374215812304)]
# Red pixel clusters:
# []
# Red pixel clusters:
# [(28.43712852177318, 67.90350260738063), (28.436664392209718, 67.90517946257764)]
# Red pixel clusters:
# []
# Red pixel clusters:
# []
# No red points found
# No red points found
# Red pixel clusters:
# []
# No red points found
# No red points found
# Red pixel clusters:
# []
# No red points found
# Red pixel clusters:
# [(28.390190396491672, 67.90771893078467), (28.388013709457077, 67.90759800372719), (28.386673146648466, 67.90724558773111), (28.386718062412672, 67.90922188135617), (28.38483160031602, 67.90580828327651)]
# No red points found
# Red pixel clusters:
# []
# Red pixel clusters:
# [(28.472237677460853, 67.90526929410605)]
# Red pixel clusters:
# [(28.490563309256892, 67.90823373454364)]
# No red points found
# No red points found
# No red points found
# No red points found
# No red points found
# No red points found
# No red points found
# No red points found
# Red pixel clusters:
# []
# No red points found
# No red points found
# No red points found
# No red points found
# No red points found
# No red points found
# No red points found
# No red points found
# Red pixel clusters:
# []
# Red pixel clusters:
# []
# No red points found
# Red pixel clusters:
# []
# No red points found
# No red points found
# Red pixel clusters:
# [(30.108788462069796, 67.90517946257764), (30.108698630541383, 67.90589811480493), (30.106877046770805, 67.91008027151653)]
# No red points found
# Processing batch number: 751
# Error processing file ../../grids_final_pak_final_version/grid_75237.shp: Image.select: Band pattern 'B4' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# Error processing file ../../grids_final_pak_final_version/grid_75229.shp: Image.select: Band pattern 'B4' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# Error processing file ../../grids_final_pak_final_version/grid_75235.shp: Image.select: Band pattern 'B4' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# Error processing file ../../grids_final_pak_final_version/grid_75239.shp: Image.select: Band pattern 'B4' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# Error processing file ../../grids_final_pak_final_version/grid_75234.shp: Image.select: Band pattern 'B4' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# Error processing file ../../grids_final_pak_final_version/grid_75236.shp: Image.select: Band pattern 'B4' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# Error processing file ../../grids_final_pak_final_version/grid_75238.shp: Image.select: Band pattern 'B4' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# Error processing file ../../grids_final_pak_final_version/grid_75228.shp: Image.select: Band pattern 'B4' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# No red points found
# No red points found
# No red points found
# No red points found
# Red pixel clusters:
# []
# Red pixel clusters:
# []
# Red pixel clusters:
# []
# Red pixel clusters:
# []
# No red points found
# Red pixel clusters:
# []
# Red pixel clusters:
# []
# No red points found
# No red points found
# No red points found
# No red points found
# No red points found
# No red points found
# No red points found
# No red points found
# No red points found
# No red points found
# No red points found
# No red points found
# No red points found
# Red pixel clusters:
# []
# No red points found
# No red points found
# No red points found
# No red points found
# Red pixel clusters:
# [(30.447812650296505, 67.9079642399584), (30.447722818768092, 67.90895238677093)]
# No red points found
# Red pixel clusters:
# []
# No red points found
# Red pixel clusters:
# []
# No red points found
# No red points found
# No red points found
# No red points found
# No red points found
# No red points found
# No red points found
# Red pixel clusters:
# []
# No red points found
# No red points found
# No red points found
# No red points found
# No red points found
# No red points found
# No red points found
# No red points found
# Red pixel clusters:
# []
# No red points found
# Red pixel clusters:
# []
# No red points found
# Red pixel clusters:
# []
# No red points found
# Red pixel clusters:
# []
# No red points found
# No red points found
# No red points found
# Red pixel clusters:
# []
# No red points found
# No red points found
# No red points found
# No red points found
# No red points found
# No red points found
# Red pixel clusters:
# []
# No red points found
# Red pixel clusters:
# []
# Red pixel clusters:
# []
# No red points found
# No red points found
# Red pixel clusters:
# []
# No red points found
# No red points found
# Red pixel clusters:
# [(30.564413974175217, 67.90967103899823)]
# No red points found
# No red points found
# No red points found
# No red points found
# No red points found
# No red points found
# No red points found
# No red points found
# No red points found
# No red points found
# No red points found
# No red points found
# No red points found
# Red pixel clusters:
# []
# Red pixel clusters:
# []
# Processing batch number: 752
# Error processing file ../../grids_final_pak_final_version/grid_75203.shp: Image.select: Band pattern 'B4' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# Error processing file ../../grids_final_pak_final_version/grid_75199.shp: Image.select: Band pattern 'B4' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# Error processing file ../../grids_final_pak_final_version/grid_75200.shp: Image.select: Band pattern 'B4' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# Error processing file ../../grids_final_pak_final_version/grid_75198.shp: Image.select: Band pattern 'B4' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# Error processing file ../../grids_final_pak_final_version/grid_75374.shp: Image.select: Band pattern 'B4' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# Error processing file ../../grids_final_pak_final_version/grid_75241.shp: Image.select: Band pattern 'B4' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# Error processing file ../../grids_final_pak_final_version/grid_75242.shp: Image.select: Band pattern 'B4' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# Error processing file ../../grids_final_pak_final_version/grid_75253.shp: Image.select: Band pattern 'B4' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# Error processing file ../../grids_final_pak_final_version/grid_75243.shp: Image.select: Band pattern 'B4' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# Error processing file ../../grids_final_pak_final_version/grid_75369.shp: Image.select: Band pattern 'B4' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# Error processing file ../../grids_final_pak_final_version/grid_75251.shp: Image.select: Band pattern 'B4' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# Error processing file ../../grids_final_pak_final_version/grid_75262.shp: Image.select: Band pattern 'B4' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# Error processing file ../../grids_final_pak_final_version/grid_75255.shp: Image.select: Band pattern 'B4' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# Error processing file ../../grids_final_pak_final_version/grid_75267.shp: Image.select: Band pattern 'B4' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# Error processing file ../../grids_final_pak_final_version/grid_75270.shp: Image.select: Band pattern 'B4' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# Error processing file ../../grids_final_pak_final_version/grid_75246.shp: Image.select: Band pattern 'B4' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# Error processing file ../../grids_final_pak_final_version/grid_75269.shp: Image.select: Band pattern 'B4' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# Error processing file ../../grids_final_pak_final_version/grid_75272.shp: Image.select: Band pattern 'B4' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# Error processing file ../../grids_final_pak_final_version/grid_75268.shp: Image.select: Band pattern 'B4' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# Error processing file ../../grids_final_pak_final_version/grid_75275.shp: Image.select: Band pattern 'B4' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# Error processing file ../../grids_final_pak_final_version/grid_75274.shp: Image.select: Band pattern 'B4' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# Error processing file ../../grids_final_pak_final_version/grid_75273.shp: Image.select: Band pattern 'B4' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# Error processing file ../../grids_final_pak_final_version/grid_75279.shp: Image.select: Band pattern 'B4' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# Error processing file ../../grids_final_pak_final_version/grid_75278.shp: Image.select: Band pattern 'B4' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# Error processing file ../../grids_final_pak_final_version/grid_75280.shp: Image.select: Band pattern 'B4' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# Error processing file ../../grids_final_pak_final_version/grid_75276.shp: Image.select: Band pattern 'B4' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# Error processing file ../../grids_final_pak_final_version/grid_75282.shp: Image.select: Band pattern 'B4' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# Error processing file ../../grids_final_pak_final_version/grid_75277.shp: Image.select: Band pattern 'B4' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# Error processing file ../../grids_final_pak_final_version/grid_75286.shp: Image.select: Band pattern 'B4' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# Error processing file ../../grids_final_pak_final_version/grid_75281.shp: Image.select: Band pattern 'B4' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# Error processing file ../../grids_final_pak_final_version/grid_75284.shp: Image.select: Band pattern 'B4' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# Error processing file ../../grids_final_pak_final_version/grid_75287.shp: Image.select: Band pattern 'B4' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# Error processing file ../../grids_final_pak_final_version/grid_75288.shp: Image.select: Band pattern 'B4' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# Error processing file ../../grids_final_pak_final_version/grid_75291.shp: Image.select: Band pattern 'B4' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# Error processing file ../../grids_final_pak_final_version/grid_75290.shp: Image.select: Band pattern 'B4' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# Error processing file ../../grids_final_pak_final_version/grid_75283.shp: Image.select: Band pattern 'B4' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# Error processing file ../../grids_final_pak_final_version/grid_75285.shp: Image.select: Band pattern 'B4' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# Error processing file ../../grids_final_pak_final_version/grid_75289.shp: Image.select: Band pattern 'B4' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# Error processing file ../../grids_final_pak_final_version/grid_75205.shp: Image.select: Band pattern 'B4' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# Error processing file ../../grids_final_pak_final_version/grid_75204.shp: Image.select: Band pattern 'B4' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# Error processing file ../../grids_final_pak_final_version/grid_75202.shp: Image.select: Band pattern 'B4' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# Error processing file ../../grids_final_pak_final_version/grid_75212.shp: Image.select: Band pattern 'B4' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# Error processing file ../../grids_final_pak_final_version/grid_75211.shp: Image.select: Band pattern 'B4' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# Error processing file ../../grids_final_pak_final_version/grid_75201.shp: Image.select: Band pattern 'B4' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# Error processing file ../../grids_final_pak_final_version/grid_75206.shp: Image.select: Band pattern 'B4' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# Error processing file ../../grids_final_pak_final_version/grid_75232.shp: Image.select: Band pattern 'B4' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# Error processing file ../../grids_final_pak_final_version/grid_75218.shp: Image.select: Band pattern 'B4' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# Error processing file ../../grids_final_pak_final_version/grid_75245.shp: Image.select: Band pattern 'B4' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# Error processing file ../../grids_final_pak_final_version/grid_75231.shp: Image.select: Band pattern 'B4' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# Error processing file ../../grids_final_pak_final_version/grid_75214.shp: Image.select: Band pattern 'B4' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# Error processing file ../../grids_final_pak_final_version/grid_75207.shp: Image.select: Band pattern 'B4' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# Error processing file ../../grids_final_pak_final_version/grid_75208.shp: Image.select: Band pattern 'B4' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# Error processing file ../../grids_final_pak_final_version/grid_75220.shp: Image.select: Band pattern 'B4' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# Error processing file ../../grids_final_pak_final_version/grid_75248.shp: Image.select: Band pattern 'B4' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# Error processing file ../../grids_final_pak_final_version/grid_75215.shp: Image.select: Band pattern 'B4' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# Error processing file ../../grids_final_pak_final_version/grid_75244.shp: Image.select: Band pattern 'B4' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# Error processing file ../../grids_final_pak_final_version/grid_75216.shp: Image.select: Band pattern 'B4' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# Error processing file ../../grids_final_pak_final_version/grid_75223.shp: Image.select: Band pattern 'B4' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# Error processing file ../../grids_final_pak_final_version/grid_75240.shp: Image.select: Band pattern 'B4' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# Error processing file ../../grids_final_pak_final_version/grid_75210.shp: Image.select: Band pattern 'B4' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# Error processing file ../../grids_final_pak_final_version/grid_75217.shp: Image.select: Band pattern 'B4' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# Error processing file ../../grids_final_pak_final_version/grid_75209.shp: Image.select: Band pattern 'B4' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# Error processing file ../../grids_final_pak_final_version/grid_75224.shp: Image.select: Band pattern 'B4' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# Error processing file ../../grids_final_pak_final_version/grid_75222.shp: Image.select: Band pattern 'B4' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# Error processing file ../../grids_final_pak_final_version/grid_75379.shp: Image.select: Band pattern 'B4' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# Error processing file ../../grids_final_pak_final_version/grid_75257.shp: Image.select: Band pattern 'B4' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# Error processing file ../../grids_final_pak_final_version/grid_75378.shp: Image.select: Band pattern 'B4' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# Error processing file ../../grids_final_pak_final_version/grid_75367.shp: Image.select: Band pattern 'B4' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# Error processing file ../../grids_final_pak_final_version/grid_75219.shp: Image.select: Band pattern 'B4' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# Error processing file ../../grids_final_pak_final_version/grid_75213.shp: Image.select: Band pattern 'B4' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# Error processing file ../../grids_final_pak_final_version/grid_75266.shp: Image.select: Band pattern 'B4' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# Error processing file ../../grids_final_pak_final_version/grid_75233.shp: Image.select: Band pattern 'B4' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# Error processing file ../../grids_final_pak_final_version/grid_75377.shp: Image.select: Band pattern 'B4' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# Error processing file ../../grids_final_pak_final_version/grid_75368.shp: Image.select: Band pattern 'B4' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# Error processing file ../../grids_final_pak_final_version/grid_75366.shp: Image.select: Band pattern 'B4' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# Error processing file ../../grids_final_pak_final_version/grid_75252.shp: Image.select: Band pattern 'B4' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# Error processing file ../../grids_final_pak_final_version/grid_75263.shp: Image.select: Band pattern 'B4' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# Error processing file ../../grids_final_pak_final_version/grid_75230.shp: Image.select: Band pattern 'B4' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# Error processing file ../../grids_final_pak_final_version/grid_75265.shp: Image.select: Band pattern 'B4' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# Error processing file ../../grids_final_pak_final_version/grid_75254.shp: Image.select: Band pattern 'B4' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# Error processing file ../../grids_final_pak_final_version/grid_75247.shp: Image.select: Band pattern 'B4' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# Error processing file ../../grids_final_pak_final_version/grid_75376.shp: Image.select: Band pattern 'B4' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# Error processing file ../../grids_final_pak_final_version/grid_75250.shp: Image.select: Band pattern 'B4' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# Error processing file ../../grids_final_pak_final_version/grid_75261.shp: Image.select: Band pattern 'B4' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# Error processing file ../../grids_final_pak_final_version/grid_75365.shp: Image.select: Band pattern 'B4' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# Error processing file ../../grids_final_pak_final_version/grid_75221.shp: Image.select: Band pattern 'B4' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# Error processing file ../../grids_final_pak_final_version/grid_75375.shp: Image.select: Band pattern 'B4' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# Error processing file ../../grids_final_pak_final_version/grid_75256.shp: Image.select: Band pattern 'B4' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# Error processing file ../../grids_final_pak_final_version/grid_75271.shp: Image.select: Band pattern 'B4' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# Error processing file ../../grids_final_pak_final_version/grid_75249.shp: Image.select: Band pattern 'B4' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# Error processing file ../../grids_final_pak_final_version/grid_75264.shp: Image.select: Band pattern 'B4' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# Error processing file ../../grids_final_pak_final_version/grid_75258.shp: Image.select: Band pattern 'B4' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# Error processing file ../../grids_final_pak_final_version/grid_75259.shp: Image.select: Band pattern 'B4' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# Error processing file ../../grids_final_pak_final_version/grid_75260.shp: Image.select: Band pattern 'B4' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# No red points found
# No red points found
# No red points found
# No red points found
# No red points found
# No red points found
# Processing batch number: 753
# Error processing file ../../grids_final_pak_final_version/grid_75297.shp: Image.select: Band pattern 'B4' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bandsError processing file ../../grids_final_pak_final_version/grid_75293.shp: Image.select: Band pattern 'B4' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
#
# Error processing file ../../grids_final_pak_final_version/grid_75298.shp: Image.select: Band pattern 'B4' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# Error processing file ../../grids_final_pak_final_version/grid_75295.shp: Image.select: Band pattern 'B4' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# Error processing file ../../grids_final_pak_final_version/grid_75292.shp: Image.select: Band pattern 'B4' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# Error processing file ../../grids_final_pak_final_version/grid_75294.shp: Image.select: Band pattern 'B4' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# Error processing file ../../grids_final_pak_final_version/grid_75296.shp: Image.select: Band pattern 'B4' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# Error processing file ../../grids_final_pak_final_version/grid_75371.shp: Image.select: Band pattern 'B4' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# Error processing file ../../grids_final_pak_final_version/grid_75370.shp: Image.select: Band pattern 'B4' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# Error processing file ../../grids_final_pak_final_version/grid_75299.shp: Image.select: Band pattern 'B4' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# Error processing file ../../grids_final_pak_final_version/grid_75373.shp: Image.select: Band pattern 'B4' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# Error processing file ../../grids_final_pak_final_version/grid_75364.shp: Image.select: Band pattern 'B4' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# Error processing file ../../grids_final_pak_final_version/grid_75372.shp: Image.select: Band pattern 'B4' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# Error processing file ../../grids_final_pak_final_version/grid_75344.shp: '/vsipythonfilelike/7d3b2957-c211-4c8d-b142-b5adebf28bc1/7d3b2957-c211-4c8d-b142-b5adebf28bc1' not recognized as a supported file format.
# Error processing file ../../grids_final_pak_final_version/grid_75338.shp: '/vsipythonfilelike/057eea6b-f01f-437a-989d-55d3e30759de/057eea6b-f01f-437a-989d-55d3e30759de' not recognized as a supported file format.
# No red points found
# No red points found
# No red points found
# No red points found
# Red pixel clusters:
# []
# No red points found
# No red points found
# Error processing file ../../grids_final_pak_final_version/grid_75383.shp: Image.select: Band pattern 'B4' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# Error processing file ../../grids_final_pak_final_version/grid_75382.shp: Image.select: Band pattern 'B4' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# Error processing file ../../grids_final_pak_final_version/grid_75380.shp: Image.select: Band pattern 'B4' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# Red pixel clusters:
# []
# Error processing file ../../grids_final_pak_final_version/grid_75381.shp: Image.select: Band pattern 'B4' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# Error processing file ../../grids_final_pak_final_version/grid_75384.shp: Image.select: Band pattern 'B4' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# Red pixel clusters:
# []
# No red points found
# Error processing file ../../grids_final_pak_final_version/grid_75385.shp: Image.select: Band pattern 'B4' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# Error processing file ../../grids_final_pak_final_version/grid_75389.shp: Image.select: Band pattern 'B4' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# Red pixel clusters:
# []
# ...
# Red pixel clusters:
# [(27.69928229124021, 67.76755756105051)]
# Red pixel clusters:
# [(27.489031598992035, 67.76701857188004), (27.487919933827936, 67.77194807700165)]
# Red pixel clusters:
# [(27.615980823932055, 67.77044599019483)]
# Red pixel clusters:
# [(27.672557411537653, 67.7674228137579)]
# Red pixel clusters:
# [(27.66326868423507, 67.76510486579535)]
# Red pixel clusters:
# [(27.760157187915635, 67.7728576212268)]
# Processing batch number: 996
# No red points found
# No red points found
# Red pixel clusters:
# [(27.096647482888628, 67.77007284384605)]
# Red pixel clusters:
# []
# Red pixel clusters:
# []
# No red points found
# Red pixel clusters:
# [(27.03825698942086, 67.77231863205635)]
# No red points found
# Red pixel clusters:
# [(27.056178379339045, 67.77142031677224)]
# Red pixel clusters:
# []
# Red pixel clusters:
# [(26.79750849327683, 67.77213896899953), (26.79714916716318, 67.77186947441429)]
# Red pixel clusters:
# [(26.916175942309017, 67.771150822187), (26.91536745855331, 67.7719593059427), (26.914774570465788, 67.77116878849267)]
# Red pixel clusters:
# [(26.740195978150002, 67.76647958270958), (26.739522241686913, 67.76692874035163)]
# Red pixel clusters:
# [(26.833351273113195, 67.76531177284022)]
# Red pixel clusters:
# [(26.757219052784066, 67.76629991965275)]
# Red pixel clusters:
# []
# Red pixel clusters:
# []
# Red pixel clusters:
# [(27.105470222286236, 67.77138181754579)]
# Red pixel clusters:
# [(26.99405987744218, 67.7652219413118), (26.993970045913766, 67.76459312061291)]
# Red pixel clusters:
# []
# Red pixel clusters:
# [(26.780808812145047, 67.77061782178508), (26.780874688599216, 67.7703722822741)]
# Red pixel clusters:
# [(27.180280635840155, 67.77267795817)]
# No red points found
# Red pixel clusters:
# []
# Red pixel clusters:
# [(26.825221519791917, 67.76407209774814), (26.82445795180041, 67.76450328908452), (26.819517217737754, 67.76423379449928), (26.81915789162411, 67.7719593059427), (26.819059076942857, 67.77246236250181), (26.819068060095695, 67.77285762122682)]
# Red pixel clusters:
# [(26.73618050882999, 67.7721749016109)]
# No red points found
# Red pixel clusters:
# [(26.917927657113047, 67.77025250690288)]
# Red pixel clusters:
# [(27.05168680291845, 67.7704546278418), (27.051102897983768, 67.76378463685721), (27.045982500864284, 67.7667490772948), (27.045892669335874, 67.76621008812434), (27.043467218068752, 67.77034233843129)]
# Red pixel clusters:
# [(27.25984442055462, 67.76734196538233)]
# Red pixel clusters:
# [(26.813318842277333, 67.76679399305901), (26.811726827968254, 67.76623005068622)]
# Red pixel clusters:
# []
# Red pixel clusters:
# [(27.886625943743336, 67.77312711581206), (27.883796250598362, 67.76872537091987)]
# Red pixel clusters:
# [(27.121440984730327, 67.76647958270958), (27.121126574380884, 67.7673778979937), (27.119285028048438, 67.76477278366974)]
# No red points found
# Red pixel clusters:
# [(26.707766796393294, 67.76562618318965)]
# Red pixel clusters:
# [(27.19986390903396, 67.76477278366974)]
# Red pixel clusters:
# []
# Red pixel clusters:
# [(26.946514045709918, 67.76827621327782)]
# Red pixel clusters:
# [(26.88553302594418, 67.77011084949268), (26.88567813841316, 67.76989318078923), (26.882578950682944, 67.77061183301652), (26.881231477756767, 67.77007284384605), (26.880872151643118, 67.77061183301652)]
# Red pixel clusters:
# [(26.78397986509799, 67.77309118320069)]
# Red pixel clusters:
# [(27.861383284259574, 67.77007284384605), (27.858373928057773, 67.77228868821355), (27.855903561026448, 67.76324564768674), (27.853612857051942, 67.76926436009035)]
# Red pixel clusters:
# []
# Red pixel clusters:
# [(26.86973304212004, 67.76953385467557), (26.86757708543815, 67.76522194131181), (26.866633854389825, 67.76714433601983), (26.86658893862562, 67.7667490772948)]
# Red pixel clusters:
# [(27.194249438508212, 67.77213896899953)]
# Red pixel clusters:
# [(27.132849588838646, 67.76629991965275), (27.132535178489206, 67.76540160436863), (27.130120295637195, 67.77181663233875), (27.13010972722208, 67.77159997982905)]
# Red pixel clusters:
# [(27.206152116022796, 67.76414396297086)]
# Red pixel clusters:
# []
# Red pixel clusters:
# []
# Red pixel clusters:
# [(26.802898384981543, 67.76531177284022)]
# Red pixel clusters:
# [(26.961810358742287, 67.76347022650778), (26.96073238040135, 67.76309592847272), (26.958396760662634, 67.7674003558758), (26.95770505789386, 67.76683890882323)]
# Red pixel clusters:
# [(26.71854657980272, 67.77222880052794), (26.713545958054457, 67.77154009214344), (26.71261769892753, 67.7681863817494)]
# Red pixel clusters:
# [(26.77005854480924, 67.76477920020749), (26.765483553397967, 67.76567109895386)]
# Red pixel clusters:
# [(27.143809035304905, 67.76823129751361), (27.143023009431303, 67.76604165400856), (27.143000551549196, 67.76558126742545)]
# Red pixel clusters:
# [(27.107337434769654, 67.7674228137579)]
# Red pixel clusters:
# [(26.893179071035558, 67.77020759113867), (26.89147227199573, 67.77168981135746), (26.89070870400423, 67.77177964288587)]
# Red pixel clusters:
# [(26.97259014215172, 67.76710840340846)]
# Red pixel clusters:
# []
# Red pixel clusters:
# [(26.98858015420905, 67.76980334926081), (26.982830936390684, 67.76504227825498)]
# Red pixel clusters:
# []
# Red pixel clusters:
# []
# Red pixel clusters:
# [(27.239928770705692, 67.77303728428365), (27.239290966853968, 67.77156404721768), (27.23539227852089, 67.77070166454493), (27.23525753122827, 67.7719593059427), (27.232427838083293, 67.76809655022099), (27.232056534432523, 67.76759349366188)]
# Red pixel clusters:
# [(26.969715533242542, 67.77227371629215), (26.968637554901598, 67.77218388476373), (26.963876483895767, 67.7651321097834), (26.962208184082403, 67.76356647457392), (26.96225951638435, 67.76432362602769), (26.96203493756332, 67.76378463685721)]
# Red pixel clusters:
# []
# Red pixel clusters:
# [(27.912587255454387, 67.76414396297086)]
# Red pixel clusters:
# [(27.222591285722185, 67.77079149607334)]
# Red pixel clusters:
# [(26.726194509471608, 67.77180414239363), (26.722066050755153, 67.7707401637714), (26.721892804236063, 67.7650243119493), (26.720792368013022, 67.76468295214133), (26.72070253648461, 67.76679399305901), (26.720490790739067, 67.76516419247211)]
# Red pixel clusters:
# [(27.006107667425724, 67.77300618875464), (27.004094059165794, 67.76642568379253)]
# Red pixel clusters:
# [(27.022289435245632, 67.77078700449691)]
# Red pixel clusters:
# [(27.014997040099903, 67.76838529441945), (27.01494570779796, 67.7681863817494), (27.01305924570131, 67.76903978126931), (27.009683077425155, 67.77159249386834), (27.009169371027635, 67.772184732231), (27.0076712653057, 67.7729168718094), (27.007579522468177, 67.77254321087737)]
# Red pixel clusters:
# [(27.231799017384407, 67.76755756105051)]
# No red points found
# No red points found
# No red points found
# Red pixel clusters:
# []
# Red pixel clusters:
# []
# No red points found
# Red pixel clusters:
# [(28.442862767670142, 67.76378463685721)]
# No red points found
# Red pixel clusters:
# []
# Red pixel clusters:
# [(28.473854644972267, 67.77186947441429)]
# No red points found
# Red pixel clusters:
# []
# Red pixel clusters:
# []
# Red pixel clusters:
# []
# No red points found
# No red points found
# No red points found
# Red pixel clusters:
# []
# Red pixel clusters:
# []
# No red points found
# Red pixel clusters:
# []
# Red pixel clusters:
# []
# Red pixel clusters:
# []
# No red points found
# Red pixel clusters:
# []
# Red pixel clusters:
# []
# Red pixel clusters:
# []
# No red points found
# Red pixel clusters:
# [(26.879026201804344, 67.77073865399782)]
# Processing batch number: 997
# No red points found
# No red points found
# No red points found
# Red pixel clusters:
# []
# No red points found
# Red pixel clusters:
# []
# No red points found
# No red points found
# No red points found
# No red points found
# Red pixel clusters:
# []
# Red pixel clusters:
# []
# No red points found
# No red points found
# Red pixel clusters:
# [(28.123152358052007, 67.76342531074357)]
# Red pixel clusters:
# []
# No red points found
# No red points found
# No red points found
# Red pixel clusters:
# []
# Red pixel clusters:
# []
# No red points found
# No red points found
# No red points found
# Red pixel clusters:
# []
# Red pixel clusters:
# [(28.01247991504848, 67.7697135177324), (28.012300251991658, 67.76872537091987)]
# No red points found
# No red points found
# No red points found
# No red points found
# No red points found
# Red pixel clusters:
# [(28.022900372344267, 67.7689948655051)]
# Red pixel clusters:
# []
# Red pixel clusters:
# []
# No red points found
# No red points found
# Red pixel clusters:
# []
# Red pixel clusters:
# []
# No red points found
# No red points found
# No red points found
# No red points found
# Red pixel clusters:
# []
# No red points found
# Red pixel clusters:
# []
# Red pixel clusters:
# []
# No red points found
# No red points found
# Red pixel clusters:
# []
# Red pixel clusters:
# [(27.923456870392236, 67.77222880052794)]
# Red pixel clusters:
# []
# Red pixel clusters:
# []
# Red pixel clusters:
# []
# Red pixel clusters:
# []
# Red pixel clusters:
# []
# Red pixel clusters:
# [(27.89048869946505, 67.77218388476373), (27.889320889595695, 67.76773722410734), (27.88923105806728, 67.7727677896984), (27.888871731953635, 67.77249829511317)]
# Red pixel clusters:
# [(27.878002117015786, 67.76841096057044), (27.87800211701579, 67.76917452856193), (27.874319024350896, 67.76576093048227)]
# No red points found
# Red pixel clusters:
# []
# No red points found
# Red pixel clusters:
# [(27.991100011286434, 67.76791688716416)]
# No red points found
# No red points found
# Red pixel clusters:
# []
# No red points found
# Red pixel clusters:
# [(27.851277237313237, 67.76764739257892), (27.851202377706226, 67.7666293019236)]
# No red points found
# Red pixel clusters:
# [(27.865470618802316, 67.77222880052794), (27.865425703038113, 67.76863553939145), (27.865290955745493, 67.77258812664158)]
# No red points found
# Red pixel clusters:
# []
# Red pixel clusters:
# []
# Red pixel clusters:
# [(27.928361671843522, 67.76921944432614), (27.928397604454894, 67.76872537091987), (27.926402595928067, 67.76457440571117), (27.92639136698703, 67.76603042506751), (27.925163669432063, 67.76728806646528)]
# Red pixel clusters:
# []
# Red pixel clusters:
# []
# Red pixel clusters:
# [(28.384951375687237, 67.76653947039519), (28.38438244267396, 67.76854570786304)]
# Red pixel clusters:
# [(28.36578731629269, 67.76953385467557)]
# Red pixel clusters:
# []
# Red pixel clusters:
# [(28.38384345350349, 67.76562618318965), (28.38384345350349, 67.77070166454493), (28.38321463280461, 67.76917452856193), (28.381597665293192, 67.76998301231764)]
# No red points found
# No red points found
# Red pixel clusters:
# []
# Red pixel clusters:
# []
# No red points found
# No red points found
# Red pixel clusters:
# [(28.34674303226935, 67.76827621327782)]
# Red pixel clusters:
# [(28.234004464112356, 67.77258812664158)]
# Red pixel clusters:
# [(28.354648206769607, 67.76450328908452), (28.35150410327519, 67.76306598462992), (28.35033629340583, 67.76638975118117), (28.349258315064887, 67.76643466694536), (28.348180336723942, 67.76692874035163)]
# Red pixel clusters:
# [(28.16384604042262, 67.76306598462992)]
# Red pixel clusters:
# [(28.393814753157216, 67.76522194131181)]
# No red points found
# Red pixel clusters:
# [(28.22556030044163, 67.77079149607334)]
# No red points found
# No red points found
# Red pixel clusters:
# []
# No red points found
# No red points found
# Red pixel clusters:
# [(28.21945175650962, 67.77258812664158)]
# No red points found
# Red pixel clusters:
# []
# Red pixel clusters:
# [(28.3734229962077, 67.7689948655051), (28.3658771478211, 67.76665924576639), (28.3658771478211, 67.77133048524382)]
# Processing batch number: 998
# No red points found
# No red points found
# Red pixel clusters:
# []
# Red pixel clusters:
# []
# No red points found
# Red pixel clusters:
# []
# No red points found
# No red points found
# Red pixel clusters:
# []
# No red points found
# No red points found
# No red points found
# Red pixel clusters:
# []
# No red points found
# No red points found
# No red points found
# No red points found
# No red points found
# No red points found
# No red points found
# Red pixel clusters:
# []
# No red points found
# No red points found
# Red pixel clusters:
# [(29.742904646847915, 67.77267795817)]
# Red pixel clusters:
# []
# No red points found
# Red pixel clusters:
# []
# Red pixel clusters:
# [(29.130747696484665, 67.77079149607334)]
# Red pixel clusters:
# []
# No red points found
# Red pixel clusters:
# []
# Red pixel clusters:
# []
# No red points found
# Red pixel clusters:
# []
# No red points found
# Red pixel clusters:
# []
# No red points found
# No red points found
# Red pixel clusters:
# []
# No red points found
# No red points found
# No red points found
# No red points found
# Red pixel clusters:
# []
# Red pixel clusters:
# []
# No red points found
# No red points found
# Red pixel clusters:
# []
# No red points found
# No red points found
# No red points found
# No red points found
# Red pixel clusters:
# []
# No red points found
# Red pixel clusters:
# []
# No red points found
# Red pixel clusters:
# []
# No red points found
# No red points found
# Red pixel clusters:
# []
# No red points found
# No red points found
# No red points found
# No red points found
# No red points found
# No red points found
# No red points found
# No red points found
# Red pixel clusters:
# []
# No red points found
# Red pixel clusters:
# []
# No red points found
# Red pixel clusters:
# [(29.13092735954149, 67.77016267537446)]
# No red points found
# No red points found
# No red points found
# No red points found
# Red pixel clusters:
# []
# Red pixel clusters:
# []
# No red points found
# No red points found
# Red pixel clusters:
# []
# Red pixel clusters:
# []
# No red points found
# No red points found
# No red points found
# No red points found
# No red points found
# No red points found
# No red points found
# No red points found
# No red points found
# No red points found
# No red points found
# No red points found
# No red points found
# Red pixel clusters:
# []
# No red points found
# No red points found
# Red pixel clusters:
# [(29.245597305559347, 67.75336417956143)]
# Processing batch number: 999
# No red points found
# No red points found
# No red points found
# No red points found
# No red points found
# No red points found
# No red points found
# No red points found
# No red points found
# No red points found
# No red points found
# Red pixel clusters:
# [(30.55260112818905, 67.76667557877155), (30.552376549368024, 67.76607534083172)]
# Red pixel clusters:
# []
# No red points found
# Red pixel clusters:
# [(30.395306121939722, 67.77222880052794), (30.390859461283327, 67.76845587633464)]
# No red points found
# No red points found
# No red points found
# Red pixel clusters:
# []
# No red points found
# No red points found
# No red points found
# Red pixel clusters:
# []
# Red pixel clusters:
# []
# No red points found
# No red points found
# No red points found
# Red pixel clusters:
# []
# Red pixel clusters:
# []
# No red points found
# Red pixel clusters:
# [(30.48221812567828, 67.76414396297086)]
# No red points found
# No red points found
# No red points found
# No red points found
# No red points found
# No red points found
# Red pixel clusters:
# []
# Red pixel clusters:
# [(29.3707326246372, 67.76387446838562)]
# No red points found
# No red points found
# Red pixel clusters:
# []
# No red points found
# Red pixel clusters:
# []
# No red points found
# Red pixel clusters:
# []
# No red points found
# No red points found
# No red points found
# No red points found
# Red pixel clusters:
# [(30.55318503312372, 67.76638975118117)]
# No red points found
# No red points found
# Red pixel clusters:
# []
# Red pixel clusters:
# []
# No red points found
# No red points found
# No red points found
# No red points found
# Red pixel clusters:
# []
# No red points found
# No red points found
# No red points found
# No red points found
# Red pixel clusters:
# []
# Red pixel clusters:
# []
# No red points found
# No red points found
# No red points found
# No red points found
# No red points found
# Red pixel clusters:
# []
# No red points found
# No red points found
# Red pixel clusters:
# []
# No red points found
# No red points found
# No red points found
# Red pixel clusters:
# [(28.925797064412798, 67.75731676681156)]
# No red points found
# No red points found
# No red points found
# No red points found
# No red points found
# No red points found
# No red points found
# Red pixel clusters:
# []
# Red pixel clusters:
# []
# No red points found
# Red pixel clusters:
# []
# No red points found
# No red points found
# No red points found
# No red points found
# No red points found
# No red points found
# Red pixel clusters:
# []
# No red points found
# No red points found
# No red points found
